# %% [markdown]
#  ## <center>Exploratory Data Analysis(EDA)<center/>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('D:\Employee\employee.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## Data Pre-Procesing

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
def segment_model(EducationField):
    if 'Life Sciences' in EducationField:
        return 'Sains'
    elif 'Technical Degree' in EducationField:
        return 'Technical'
    elif 'Medical' in EducationField:
        return 'Health'
    elif 'Marketing' in EducationField:
        return 'Management'
    elif 'Human Resources' in EducationField:
        return 'Psychology'
    else:
        'Other'
        
df['EducationField'] = df['EducationField'].apply(segment_model)

# %%
plt.figure(figsize=(10,5))
df['EducationField'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#list Category to Plot
cat_vars = ['Department', 'EducationField', 'JobRole', 'Gender', 'Age', 'YearsAtCompany']
             
#create figure with subplot
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))
axs = axs.ravel()

#create bar plot for each category list
for i, var in enumerate(cat_vars):
    sns.barplot(x=var, y='MonthlyIncome', data=df, ax=axs[i], estimator=np.mean)
    axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=90)
    
#adjust spasing between subplots
fig.tight_layout()

#show plot
plt.show()

# %%
cat_vars = ['JobLevel', 'HourlyRate']

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20,10))

for i, var in enumerate(cat_vars):
    sns.boxplot(x=var, data=df, ax=axs[i])
    
fig.tight_layout()

plt.show()

# %%
cat_vars = ['JobLevel', 'HourlyRate']

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20,10))

for i, var in enumerate(cat_vars):
    sns.violinplot(x=var, data=df, ax=axs[i])
    
fig.tight_layout()

plt.show()

# %%
num_vars = ['WorkLifeBalance', 'TrainingTimesLastYear', 'TotalWorkingYears', 'TotalWorkingYears']

fig, axs = plt.subplots(nrows=2, ncols=2, figsize = (20,10))
axs = axs.flatten()

for i, var in enumerate(num_vars):
    sns.boxplot(x=var, data=df, ax=axs[i])

fig.tight_layout()

plt.show()

# %%
num_vars = ['MaritalStatus', 'Gender']

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15,15))
axs = axs.flatten()

for i, vars in enumerate(num_vars):
    sns.violinplot(y=var, data=df, x='Gender', ax=axs[i])
    
fig.tight_layout()
plt.show()

# %%
num_vars = ['MonthlyIncome', 'MonthlyRate'] 

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15,15))
axs = axs.flatten()

for i, vars in enumerate(num_vars):
    sns.boxplot(y=var, data=df, x='Gender', ax=axs[i])
    
fig.tight_layout()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (12,6)
sns.countplot(df['Gender'], palette='pink')
plt.title('Gender', fontsize=15)
plt.show()

# %%
plt.figure(figsize = (10, 6))
ax = sns.countplot(x = 'MaritalStatus', data=df, palette = 'pastel')
ax.set_title('Count of MaritalStatus', fontsize=15)

plt.show()
